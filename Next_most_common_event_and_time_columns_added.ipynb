# %%
import pandas as pd
import matplotlib.pyplot as plt
import pm4py
import numpy as np
import datetime
pd.set_option("display.max_rows", None)
from collections import Counter
import operator
import pickle

# %%
log = pm4py.read_xes('./BPI_Challenge_2012.xes.gz')
df = pm4py.convert_to_dataframe(log)
# Out:
# HBox(children=(HTML(value='parsing log, completed traces :: '), FloatProgress(value=0.0, max=13087.0), HTML(va…

# %%
print('DataFrame size: {}'.format(len(df)))
print('DataFrame without nulls size: {}'.format(len(df.dropna())))
# Out:
# DataFrame size: 262200
# DataFrame without nulls size: 244190

# %%
df.dropna(inplace=True)
df.describe()
# Out:
#        org:resource lifecycle:transition            concept:name  \
# count        244190               244190                  244190
# unique           68                    3                      24
# top             112             COMPLETE  W_Completeren aanvraag
# freq          45687               156364                   48372
#
#                           time:timestamp                     case:REG_DATE  \
# count                             244190                            244190
# unique                            230197                             13087
# top     2012-01-17 10:11:21.961000+01:00  2011-12-22 21:51:37.590000+01:00
# freq                                   4                               168
#
#        case:concept:name case:AMOUNT_REQ
# count             244190          244190
# unique             13087             631
# top               195247            5000
# freq                 168           30855

# %%
case = 'blib'
first_item = []
for index, row in df.iterrows():
    if case != row['case:concept:name']:
        case = row['case:concept:name']
        task = row['concept:name']
        first_item.append(task)
print(Counter(first_item))
# Out:
# Counter({'A_SUBMITTED': 13087})

# %%
Counter(first_item)
# Out:
# Counter({'A_SUBMITTED': 13087})

# %%
def nth_most_common(w, n):
    sort = dict(sorted(Counter(w).items(), key=lambda item: item[1]))
    return str(list(sort)[-n])

# %%
def get_max(task):
    previous = 'blibs'
    empty = []
    case = 'blib'
    for index, row in df.iterrows():
        t = row['concept:name']
        c = row['case:concept:name']
        if (case == c) & (previous == task):
            empty.append(t)
        case = c
        previous = t
    return nth_most_common(empty, 1)

# %%
get_max('A_ACCEPTED')
# Out:
# 'O_SELECTED'

# %%
caselist = list(df['concept:name'].unique())

# %%
next_common = {}
for value in caselist:
    next_common[value] = get_max(value)

# %%
 next_common
# Out:
# {'A_SUBMITTED': 'A_PARTLYSUBMITTED',
#  'A_PARTLYSUBMITTED': 'A_PREACCEPTED',
#  'A_PREACCEPTED': 'W_Completeren aanvraag',
#  'W_Completeren aanvraag': 'W_Completeren aanvraag',
#  'A_ACCEPTED': 'O_SELECTED',
#  'O_SELECTED': 'O_CREATED',
#  'A_FINALIZED': 'O_CREATED',
#  'O_CREATED': 'O_SENT',
#  'O_SENT': 'W_Nabellen offertes',
#  'W_Nabellen offertes': 'W_Nabellen offertes',
#  'O_SENT_BACK': 'W_Valideren aanvraag',
#  'W_Valideren aanvraag': 'W_Valideren aanvraag',
#  'A_REGISTERED': 'A_ACTIVATED',
#  'A_APPROVED': 'A_ACTIVATED',
#  'O_ACCEPTED': 'A_REGISTERED',
#  'A_ACTIVATED': 'W_Valideren aanvraag',
#  'O_CANCELLED': 'O_SELECTED',
#  'W_Wijzigen contractgegevens': 'W_Wijzigen contractgegevens',
#  'A_DECLINED': 'W_Afhandelen leads',
#  'A_CANCELLED': 'O_CANCELLED',
#  'W_Afhandelen leads': 'W_Afhandelen leads',
#  'O_DECLINED': 'A_DECLINED',
#  'W_Nabellen incomplete dossiers': 'W_Nabellen incomplete dossiers',
#  'W_Beoordelen fraude': 'W_Beoordelen fraude'}

# %%
with open('next_common_event.pkl', 'wb') as f:
    pickle.dump(a, f)

# %%
with open('next_common_event.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)

# %%
loaded_dict
# Out:
# [['A_SUBMITTED', '0 days 00:00:00.581691655'],
#  ['A_PARTLYSUBMITTED', '0 days 01:01:20.356231880'],
#  ['A_PREACCEPTED', '0 days 02:04:54.228496869'],
#  ['W_Completeren aanvraag', '0 days 08:40:17.229487175'],
#  ['A_ACCEPTED', '0 days 08:00:42.411919642'],
#  ['O_SELECTED', '0 days 07:12:11.466512821'],
#  ['A_FINALIZED', '0 days 06:43:09.900357195'],
#  ['O_CREATED', '0 days 06:08:28.321527951'],
#  ['O_SENT', '0 days 10:40:10.900425471'],
#  ['W_Nabellen offertes', '0 days 18:40:50.682267246'],
#  ['O_SENT_BACK', '0 days 19:40:24.803281383'],
#  ['W_Valideren aanvraag', '0 days 18:40:09.228862896'],
#  ['A_REGISTERED', '0 days 16:10:59.567745959'],
#  ['A_APPROVED', '0 days 15:00:13.220079862'],
#  ['O_ACCEPTED', '0 days 13:58:37.092804743'],
#  ['A_ACTIVATED', '0 days 10:37:04.191335731'],
#  ['O_CANCELLED', '0 days 07:06:06.679006013'],
#  ['A_DECLINED', '0 days 05:10:39.946601047'],
#  ['A_CANCELLED', '0 days 00:01:54.501236994'],
#  ['W_Afhandelen leads', '0 days 00:03:03.999699108'],
#  ['O_DECLINED', '-1 days +23:03:35.456204528'],
#  ['W_Nabellen incomplete dossiers', '0 days 00:00:37.705275266'],
#  ['W_Beoordelen fraude', '0 days 00:01:20.024146315']]

# %%
a=[["A_SUBMITTED", "0 days 00:00:00.581691655"],["A_PARTLYSUBMITTED", "0 days 01:01:20.356231880"],["A_PREACCEPTED", "0 days 02:04:54.228496869"],
["W_Completeren aanvraag","0 days 08:40:17.229487175"],["A_ACCEPTED","0 days 08:00:42.411919642"],["O_SELECTED","0 days 07:12:11.466512821"],
["A_FINALIZED","0 days 06:43:09.900357195"],['O_CREATED', '0 days 06:08:28.321527951'],["O_SENT", "0 days 10:40:10.900425471"],
["W_Nabellen offertes","0 days 18:40:50.682267246"],["O_SENT_BACK","0 days 19:40:24.803281383"],["W_Valideren aanvraag", "0 days 18:40:09.228862896"],
["A_REGISTERED","0 days 16:10:59.567745959"],["A_APPROVED","0 days 15:00:13.220079862"],["O_ACCEPTED","0 days 13:58:37.092804743"],
["A_ACTIVATED", "0 days 10:37:04.191335731"],["O_CANCELLED", "0 days 07:06:06.679006013"],["A_DECLINED","0 days 05:10:39.946601047"],
["A_CANCELLED", "0 days 00:01:54.501236994"],["W_Afhandelen leads", "0 days 00:03:03.999699108"],["O_DECLINED", "-1 days +23:03:35.456204528"],
["W_Nabellen incomplete dossiers", "0 days 00:00:37.705275266"],["W_Beoordelen fraude", "0 days 00:01:20.024146315"]]

# %%
d = {}
for value in a:
    d[value[0]] = value[1]

d
# Out:
# {'A_SUBMITTED': '0 days 00:00:00.581691655',
#  'A_PARTLYSUBMITTED': '0 days 01:01:20.356231880',
#  'A_PREACCEPTED': '0 days 02:04:54.228496869',
#  'W_Completeren aanvraag': '0 days 08:40:17.229487175',
#  'A_ACCEPTED': '0 days 08:00:42.411919642',
#  'O_SELECTED': '0 days 07:12:11.466512821',
#  'A_FINALIZED': '0 days 06:43:09.900357195',
#  'O_CREATED': '0 days 06:08:28.321527951',
#  'O_SENT': '0 days 10:40:10.900425471',
#  'W_Nabellen offertes': '0 days 18:40:50.682267246',
#  'O_SENT_BACK': '0 days 19:40:24.803281383',
#  'W_Valideren aanvraag': '0 days 18:40:09.228862896',
#  'A_REGISTERED': '0 days 16:10:59.567745959',
#  'A_APPROVED': '0 days 15:00:13.220079862',
#  'O_ACCEPTED': '0 days 13:58:37.092804743',
#  'A_ACTIVATED': '0 days 10:37:04.191335731',
#  'O_CANCELLED': '0 days 07:06:06.679006013',
#  'A_DECLINED': '0 days 05:10:39.946601047',
#  'A_CANCELLED': '0 days 00:01:54.501236994',
#  'W_Afhandelen leads': '0 days 00:03:03.999699108',
#  'O_DECLINED': '-1 days +23:03:35.456204528',
#  'W_Nabellen incomplete dossiers': '0 days 00:00:37.705275266',
#  'W_Beoordelen fraude': '0 days 00:01:20.024146315'}

# %%
df['next_event'] = df['concept:name'].map(next_common)

# %%
df['time_until_next'] = df['concept:name'].map(d)

# %%
df.iloc[-100:]
# Out:
#        org:resource lifecycle:transition            concept:name  \
# 262100        11169             COMPLETE  W_Completeren aanvraag
# 262101        11299                START  W_Completeren aanvraag
# 262102        11299             COMPLETE              A_ACCEPTED
# 262103        11299             COMPLETE              O_SELECTED
# 262104        11299             COMPLETE             A_FINALIZED
# 262105        11299             COMPLETE               O_CREATED
# 262106        11299             COMPLETE                  O_SENT
# 262107        11299             SCHEDULE     W_Nabellen offertes
# 262108        11299             COMPLETE  W_Completeren aanvraag
# 262109        11302                START     W_Nabellen offertes
# 262110        11302             COMPLETE     W_Nabellen offertes
# 262111          112             COMPLETE             A_SUBMITTED
# 262112          112             COMPLETE       A_PARTLYSUBMITTED
# 262113          112             COMPLETE           A_PREACCEPTED
# 262114          112             SCHEDULE  W_Completeren aanvraag
# 262115        11203                START  W_Completeren aanvraag
# 262116        11203             COMPLETE  W_Completeren aanvraag
# 262117        10982                START  W_Completeren aanvraag
# 262118        10982             COMPLETE              A_ACCEPTED
# 262119        10982             COMPLETE             A_FINALIZED
# 262120        10982             COMPLETE              O_SELECTED
# 262121        10982             COMPLETE               O_CREATED
# 262122        10982             COMPLETE                  O_SENT
# 262123        10982             SCHEDULE     W_Nabellen offertes
# 262124        10982             COMPLETE  W_Completeren aanvraag
# 262125        10982                START     W_Nabellen offertes
# 262126        10982             COMPLETE     W_Nabellen offertes
# 262127        10932                START     W_Nabellen offertes
# 262128        10932             COMPLETE     W_Nabellen offertes
# 262129        10899                START     W_Nabellen offertes
# 262130        10899             COMPLETE             O_SENT_BACK
# 262131        10899             SCHEDULE    W_Valideren aanvraag
# 262132        10899             COMPLETE     W_Nabellen offertes
# 262133        10809                START    W_Valideren aanvraag
# 262134        10809             COMPLETE    W_Valideren aanvraag
# 262135        10138                START    W_Valideren aanvraag
# 262136        10138             COMPLETE              A_DECLINED
# 262137        10138             COMPLETE              O_DECLINED
# 262138        10138             COMPLETE    W_Valideren aanvraag
# 262139          112             COMPLETE             A_SUBMITTED
# 262140          112             COMPLETE       A_PARTLYSUBMITTED
# 262141          112             COMPLETE           A_PREACCEPTED
# 262142          112             SCHEDULE  W_Completeren aanvraag
# 262143        11169                START  W_Completeren aanvraag
# 262144        11169             COMPLETE  W_Completeren aanvraag
# 262145        11003                START  W_Completeren aanvraag
# 262146        11003             COMPLETE              A_ACCEPTED
# 262147        11003             COMPLETE             A_FINALIZED
# 262148        11003             COMPLETE              O_SELECTED
# 262149        11003             COMPLETE               O_CREATED
# 262150        11003             COMPLETE                  O_SENT
# 262151        11003             SCHEDULE     W_Nabellen offertes
# 262152        11003             COMPLETE  W_Completeren aanvraag
# 262153        11003                START     W_Nabellen offertes
# 262154        11003             COMPLETE              O_SELECTED
# 262155        11003             COMPLETE             O_CANCELLED
# 262156        11003             COMPLETE               O_CREATED
# 262157        11003             COMPLETE                  O_SENT
# 262158        11003             SCHEDULE     W_Nabellen offertes
# 262159        11003             COMPLETE     W_Nabellen offertes
# 262160        11003                START     W_Nabellen offertes
# 262161        11003             COMPLETE     W_Nabellen offertes
# 262162        11003                START     W_Nabellen offertes
# 262163        11003             COMPLETE     W_Nabellen offertes
# 262164        10789                START     W_Nabellen offertes
# 262165        10789             COMPLETE             O_SENT_BACK
# 262166        10789             SCHEDULE    W_Valideren aanvraag
# 262167        10789             COMPLETE     W_Nabellen offertes
# 262168          112             COMPLETE             A_SUBMITTED
# 262169          112             COMPLETE       A_PARTLYSUBMITTED
# 262170          112             COMPLETE              A_DECLINED
# 262171          112             COMPLETE             A_SUBMITTED
# 262172          112             COMPLETE       A_PARTLYSUBMITTED
# 262173          112             SCHEDULE      W_Afhandelen leads
# 262174        11169                START      W_Afhandelen leads
# 262175        11169             COMPLETE              A_DECLINED
# 262176        11169             COMPLETE      W_Afhandelen leads
# 262177          112             COMPLETE             A_SUBMITTED
# 262178          112             COMPLETE       A_PARTLYSUBMITTED
# 262179          112             SCHEDULE      W_Afhandelen leads
# 262180        11169                START      W_Afhandelen leads
# 262181        11169             COMPLETE           A_PREACCEPTED
# 262182        11169             SCHEDULE  W_Completeren aanvraag
# 262183        11169             COMPLETE      W_Afhandelen leads
# 262184        10933                START  W_Completeren aanvraag
# 262185        10933             COMPLETE              A_ACCEPTED
# 262192  2012-03-10 12:46:22.700000+01:00  2012-02-29 23:43:09.766000+01:00
# 262193  2012-03-10 12:50:54.881000+01:00  2012-02-29 23:43:09.766000+01:00
# 262194  2012-02-29 23:51:16.799000+01:00  2012-02-29 23:51:16.799000+01:00
# 262195  2012-02-29 23:51:17.423000+01:00  2012-02-29 23:51:16.799000+01:00
# 262196  2012-02-29 23:52:01.287000+01:00  2012-02-29 23:51:16.799000+01:00
# 262197  2012-03-01 09:26:46.736000+01:00  2012-02-29 23:51:16.799000+01:00
# 262198  2012-03-01 09:27:37.118000+01:00  2012-02-29 23:51:16.799000+01:00
# 262199  2012-03-01 09:27:41.325000+01:00  2012-02-29 23:51:16.799000+01:00
#
#        case:concept:name case:AMOUNT_REQ              next_event  \
# 262100            214358            3500  W_Completeren aanvraag
# 262101            214358            3500  W_Completeren aanvraag
# 262102            214358            3500              O_SELECTED
# 262103            214358            3500               O_CREATED
# 262104            214358            3500               O_CREATED
# 262105            214358            3500                  O_SENT
# 262106            214358            3500     W_Nabellen offertes
# 262107            214358            3500     W_Nabellen offertes
# 262108            214358            3500  W_Completeren aanvraag
# 262109            214358            3500     W_Nabellen offertes
# 262110            214358            3500     W_Nabellen offertes
# 262111            214361            5000       A_PARTLYSUBMITTED
# 262112            214361            5000           A_PREACCEPTED
# 262113            214361            5000  W_Completeren aanvraag
# 262114            214361            5000  W_Completeren aanvraag
# 262115            214361            5000  W_Completeren aanvraag
# 262116            214361            5000  W_Completeren aanvraag
# 262117            214361            5000  W_Completeren aanvraag
# 262118            214361            5000              O_SELECTED
# 262119            214361            5000               O_CREATED
# 262120            214361            5000               O_CREATED
# 262121            214361            5000                  O_SENT
# 262122            214361            5000     W_Nabellen offertes
# 262123            214361            5000     W_Nabellen offertes
# 262124            214361            5000  W_Completeren aanvraag
# 262125            214361            5000     W_Nabellen offertes
# 262126            214361            5000     W_Nabellen offertes
# 262127            214361            5000     W_Nabellen offertes
# 262128            214361            5000     W_Nabellen offertes
# 262129            214361            5000     W_Nabellen offertes
# 262130            214361            5000    W_Valideren aanvraag
# 262131            214361            5000    W_Valideren aanvraag
# 262132            214361            5000     W_Nabellen offertes
# 262133            214361            5000    W_Valideren aanvraag
# 262134            214361            5000    W_Valideren aanvraag
# 262135            214361            5000    W_Valideren aanvraag
# 262136            214361            5000      W_Afhandelen leads
# 262137            214361            5000              A_DECLINED
# 262138            214361            5000    W_Valideren aanvraag
# 262139            214364            5000       A_PARTLYSUBMITTED
# 262140            214364            5000           A_PREACCEPTED
# 262141            214364            5000  W_Completeren aanvraag
# 262142            214364            5000  W_Completeren aanvraag
# 262143            214364            5000  W_Completeren aanvraag
# 262144            214364            5000  W_Completeren aanvraag
# 262145            214364            5000  W_Completeren aanvraag
# 262146            214364            5000              O_SELECTED
# 262147            214364            5000               O_CREATED
# 262148            214364            5000               O_CREATED
# 262149            214364            5000                  O_SENT
# 262150            214364            5000     W_Nabellen offertes
# 262151            214364            5000     W_Nabellen offertes
# 262152            214364            5000  W_Completeren aanvraag
# 262153            214364            5000     W_Nabellen offertes
# 262154            214364            5000               O_CREATED
# 262155            214364            5000              O_SELECTED
# 262156            214364            5000                  O_SENT
# 262157            214364            5000     W_Nabellen offertes
# 262158            214364            5000     W_Nabellen offertes
# 262159            214364            5000     W_Nabellen offertes
# 262160            214364            5000     W_Nabellen offertes
# 262161            214364            5000     W_Nabellen offertes
# 262162            214364            5000     W_Nabellen offertes
# 262163            214364            5000     W_Nabellen offertes
# 262164            214364            5000     W_Nabellen offertes
# 262165            214364            5000    W_Valideren aanvraag
# 262166            214364            5000    W_Valideren aanvraag
# 262167            214364            5000     W_Nabellen offertes
# 262168            214367             500       A_PARTLYSUBMITTED
# 262169            214367             500           A_PREACCEPTED
# 262170            214367             500      W_Afhandelen leads
# 262171            214370           20000       A_PARTLYSUBMITTED
# 262172            214370           20000           A_PREACCEPTED
# 262173            214370           20000      W_Afhandelen leads
# 262174            214370           20000      W_Afhandelen leads
# 262175            214370           20000      W_Afhandelen leads
# 262176            214370           20000      W_Afhandelen leads
# 262177            214373            8500       A_PARTLYSUBMITTED
# 262178            214373            8500           A_PREACCEPTED
# 262179            214373            8500      W_Afhandelen leads
# 262180            214373            8500      W_Afhandelen leads
# 262181            214373            8500  W_Completeren aanvraag
# 262182            214373            8500  W_Completeren aanvraag
# 262183            214373            8500      W_Afhandelen leads
# 262184            214373            8500  W_Completeren aanvraag
# 262185            214373            8500              O_SELECTED
# 262186            214373            8500               O_CREATED
# 262187            214373            8500               O_CREATED
# 262188            214373            8500                  O_SENT
# 262189            214373            8500     W_Nabellen offertes
# 262190            214373            8500     W_Nabellen offertes
# 262191            214373            8500  W_Completeren aanvraag
# 262192            214373            8500     W_Nabellen offertes
# 262193            214373            8500     W_Nabellen offertes
# 262194            214376           15000       A_PARTLYSUBMITTED
# 262195            214376           15000           A_PREACCEPTED
# 262196            214376           15000      W_Afhandelen leads
# 262197            214376           15000      W_Afhandelen leads
# 262198            214376           15000      W_Afhandelen leads
# 262199            214376           15000      W_Afhandelen leads
#
#                     time_until_next
# 262100    0 days 08:40:17.229487175
# 262101    0 days 08:40:17.229487175
# 262102    0 days 08:00:42.411919642
# 262103    0 days 07:12:11.466512821
# 262104    0 days 06:43:09.900357195
# 262105    0 days 06:08:28.321527951
# 262106    0 days 10:40:10.900425471
# 262107    0 days 18:40:50.682267246
# 262108    0 days 08:40:17.229487175
# 262109    0 days 18:40:50.682267246
# 262110    0 days 18:40:50.682267246
# 262111    0 days 00:00:00.581691655
# 262112    0 days 01:01:20.356231880
# 262113    0 days 02:04:54.228496869
# 262114    0 days 08:40:17.229487175
# 262115    0 days 08:40:17.229487175
# 262116    0 days 08:40:17.229487175
# 262117    0 days 08:40:17.229487175
# 262118    0 days 08:00:42.411919642
# 262119    0 days 06:43:09.900357195
# 262120    0 days 07:12:11.466512821
